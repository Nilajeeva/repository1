# %%
print {hello}
# Out:
#   Cell In[1], line 1
#     print {hello}
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print (hello)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print (hello)
#
# NameError: name 'hello' is not defined

# %%
print {"hello"}
# Out:
#   Cell In[3], line 1
#     print {"hello"}
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print ("hello")
# Out:
# hello

# %%
a=[1, 2, 3, 4]
b=[3, 5, 7, 9]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot (a,b)

# %%
plt.xlabel ('x-axis')
plt.ylabel ('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')

# %%
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
a=[1, 2, 3, 4]
b=[3, 5, 7, 9]

# %%
plt.plot (a, b)
plt.xlabel ('x-axis')
plt.ylabel ('y-axis')
plt.show ()

# %% [markdown]
# # addition
# here shows

# %% [markdown]
# __jeeva__

# %% [markdown]
# _nila_

# %% [markdown]
# line <br> break

# %% [markdown]
# line
# brek

# %% [markdown]
# # MAIN
#   ## 1. TILTLE 1
#    ### 1. zero

# %% [markdown]
#   ## 2. title 2

# %% [markdown]
# <font color = red> NILA </font>

# %% [markdown]
# <font color=brown> Jeeva </font>

# %% [markdown]
# # JEEVA
# ***
# # nila

# %% [markdown]
# > jeeva is a cute girl

# %% [markdown]
# 'jeeva is a cute girl'

# %% [markdown]
# jeeva is a 'cute girl'

# %% [markdown]
# $ j=x+y $

# %% [markdown]
# [1](#hello)

# %% [markdown]
# <a id="hello"></a/>

# %% [markdown]
# [click me](http://google.com)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo ('szvt1vD0Uug', width=500, height=300)

# %%
from IPython.display import IFrame
IFrame('file:///G:/DOCUMENTS/jeeva-JEEVANILA/img20230329_16385886.pdf', width=800, height=500)
# Out:
#         <iframe
#             width="800"
#             height="500"
#             src="file:///G:/DOCUMENTS/jeeva-JEEVANILA/img20230329_16385886.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import IFrame
IFrame('https://www.bing.com/search?q=monospace+font+in+jupyter&qs=n&form=QBRE&sp=-1&ghc=1&lq=0&pq=monospace+font+in+jupyter&sc=10-25&sk=&cvid=3E5BBCEACD324193B73DD2D899D5090C&ghsh=0&ghacc=0&ghpl=',width=800, height=300)
# Out:
#         <iframe
#             width="800"
#             height="300"
#             src="https://www.bing.com/search?q=monospace+font+in+jupyter&qs=n&form=QBRE&sp=-1&ghc=1&lq=0&pq=monospace+font+in+jupyter&sc=10-25&sk=&cvid=3E5BBCEACD324193B73DD2D899D5090C&ghsh=0&ghacc=0&ghpl="
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import Image
Image('G:\DOCUMENTS\jeeva-JEEVANILA\IMG_20230411_111109489.jpg',width=300, height=300)

# %%
# !pip install jupyterthemes
# Out:
# ...
#      ---------------------------------------- 7.0/7.0 MB 466.9 kB/s eta 0:00:00
# ...
#      -------------------------------------- 46.7/46.7 kB 775.8 kB/s eta 0:00:00
# ...

# %%
# !jt -l
# Out:
# Available Themes:
#    chesterish
#    grade3
#    gruvboxd
#    gruvboxl
#    monokai
#    oceans16
#    onedork
#    solarizedd
#    solarizedl

# %%
# !jt -t chesterish
